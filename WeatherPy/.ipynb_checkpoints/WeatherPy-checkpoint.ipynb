# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %%
#Perform API call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
params = {
    "units": "imperial",
    "appid": api_key
}

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

record_count = 1
set_count = 1

print("Beginning Data Retrieval")
print("------------------------")

for i,city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 0
        
    try:
     city_url = url + "appid=" + api_key + "&units=" + units + "&q=" + city
     response = requests.get(city_url).json()
        
     print(f'Processing Record {record_count} of Set {set_count} | {city}' )
    
     city_name.append(response["name"])
     cloudiness.append(response["clouds"]["all"])
     country.append(response["sys"]["country"])
     date.append(response["dt"])
     humidity.append(response["main"]["humidity"])
     lat.append(response["coord"]["lat"])
     lng.append(response["coord"]["lon"])
     max_temp.append(response["main"]["temp_max"])
     wind_speed.append(response["wind"]["speed"])
     
     record_count += 1
        
    except KeyError:
      print("City not found. Skipping...")
    
print("End of Data Retrieval")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | kalabo
# Processing Record 2 of Set 1 | san cristobal
# Processing Record 3 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | pathein
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | zapolyarnyy
# Processing Record 7 of Set 1 | les cayes
# Processing Record 8 of Set 1 | qostanay
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | terrace
# Processing Record 15 of Set 1 | banff
# Processing Record 16 of Set 1 | okha
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | bure
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 1 | miguel pereira
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | taupo
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | umm nuwarah
# City not found. Skipping...
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | bystryy istok
# Processing Record 27 of Set 1 | paamiut
# Processing Record 28 of Set 1 | kandrian
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | waitati
# Processing Record 32 of Set 1 | puerto narino
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | merauke
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | aubenas
# Processing Record 38 of Set 1 | quimper
# Processing Record 39 of Set 1 | yar-sale
# Processing Record 40 of Set 1 | ormara
# Processing Record 41 of Set 1 | iskateley
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | xam nua
# Processing Record 0 of Set 2 | farkhor
# Processing Record 1 of Set 2 | kapuskasing
# Processing Record 2 of Set 2 | alofi
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | harlingen
# Processing Record 5 of Set 2 | birao
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | ylojarvi
# Processing Record 9 of Set 2 | uzunovo
# Processing Record 10 of Set 2 | buala
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | penzance
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | acapulco
# Processing Record 18 of Set 2 | berbera
# City not found. Skipping...
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | corinto
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | cherepovets
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | severnoye
# Processing Record 26 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 2 | gobabis
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | chapais
# Processing Record 29 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | lakki marwat
# Processing Record 31 of Set 2 | leh
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | gamba
# Processing Record 34 of Set 2 | bilma
# Processing Record 35 of Set 2 | yumen
# Processing Record 36 of Set 2 | poninka
# Processing Record 37 of Set 2 | san patricio
# Processing Record 38 of Set 2 | cayenne
# Processing Record 39 of Set 2 | maua
# Processing Record 40 of Set 2 | pangkalanbuun
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | makakilo city
# Processing Record 44 of Set 2 | leshukonskoye
# Processing Record 0 of Set 3 | omboue
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | nanakuli
# Processing Record 4 of Set 3 | kahului
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 3 | hohhot
# Processing Record 6 of Set 3 | sechura
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | jacareacanga
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | bafra
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | mercedes
# Processing Record 13 of Set 3 | doha
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | rocha
# Processing Record 18 of Set 3 | bilibino
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | marsaxlokk
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 22 of Set 3 | jagtial
# Processing Record 23 of Set 3 | guerrero negro
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | takaka
# Processing Record 26 of Set 3 | kodoli
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | dodge city
# Processing Record 30 of Set 3 | hambantota
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | flinders
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | yerbogachen
# Processing Record 36 of Set 3 | sistranda
# Processing Record 37 of Set 3 | porto novo
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | bima
# Processing Record 40 of Set 3 | kuala terengganu
# Processing Record 41 of Set 3 | bambanglipuro
# Processing Record 42 of Set 3 | hailey
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | henties bay
# Processing Record 0 of Set 4 | kapaa
# Processing Record 1 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | santa fe
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | vestmannaeyjar
# Processing Record 5 of Set 4 | bathsheba
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | lompoc
# Processing Record 10 of Set 4 | andenes
# City not found. Skipping...
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | ushtobe
# Processing Record 12 of Set 4 | kamina
# Processing Record 13 of Set 4 | filadelfia
# Processing Record 14 of Set 4 | mopti
# Processing Record 15 of Set 4 | boddam
# Processing Record 16 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 16 of Set 4 | ust-maya
# Processing Record 17 of Set 4 | tautira
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | burgeo
# Processing Record 20 of Set 4 | quatre cocos
# Processing Record 21 of Set 4 | young
# Processing Record 22 of Set 4 | noyabrsk
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | boguchany
# Processing Record 25 of Set 4 | cairns
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | det udom
# Processing Record 28 of Set 4 | santa maria
# Processing Record 29 of Set 4 | nuuk
# Processing Record 30 of Set 4 | ahipara
# Processing Record 31 of Set 4 | chifeng
# Processing Record 32 of Set 4 | rio cuarto
# Processing Record 33 of Set 4 | qasigiannguit
# Processing Record 34 of Set 4 | dobryanka
# Processing Record 35 of Set 4 | lisakovsk
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | rudbar
# City not found. Skipping...
# Processing Record 37 of Set 4 | rock sound
# Processing Record 38 of Set 4 | pangnirtung
# Processing Record 39 of Set 4 | khilok
# Processing Record 40 of Set 4 | lavrentiya
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | sao joao da barra
# Processing Record 45 of Set 4 | victoria
# Processing Record 0 of Set 5 | olafsvik
# City not found. Skipping...
# Processing Record 0 of Set 5 | warwick
# Processing Record 1 of Set 5 | zhigansk
# Processing Record 2 of Set 5 | katsuura
# Processing Record 3 of Set 5 | horki
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | seoul
# Processing Record 6 of Set 5 | kalat
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 5 | meadow lake
# Processing Record 8 of Set 5 | carutapera
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | daitari
# Processing Record 11 of Set 5 | ondangwa
# Processing Record 12 of Set 5 | san antonio
# Processing Record 13 of Set 5 | comodoro rivadavia
# Processing Record 14 of Set 5 | bonavista
# Processing Record 15 of Set 5 | nizhneudinsk
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | carnarvon
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | barcelos
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | pandan
# Processing Record 22 of Set 5 | emure
# Processing Record 23 of Set 5 | saryozek
# Processing Record 24 of Set 5 | ilulissat
# Processing Record 25 of Set 5 | sibolga
# Processing Record 26 of Set 5 | beringovskiy
# Processing Record 27 of Set 5 | innisfail
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | mvangue
# Processing Record 32 of Set 5 | shiyan
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | biak
# Processing Record 36 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 36 of Set 5 | krasnokamensk
# Processing Record 37 of Set 5 | kyabe
# Processing Record 38 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | mizdah
# Processing Record 41 of Set 5 | vynohradove
# Processing Record 42 of Set 5 | ayan
# Processing Record 43 of Set 5 | poletayevo
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | chojnice
# Processing Record 0 of Set 6 | fortuna
# Processing Record 1 of Set 6 | kangaba
# Processing Record 2 of Set 6 | keti bandar
# Processing Record 3 of Set 6 | goderich
# Processing Record 4 of Set 6 | lahaina
# Processing Record 5 of Set 6 | palencia
# Processing Record 6 of Set 6 | vilcun
# Processing Record 7 of Set 6 | saint-georges
# Processing Record 8 of Set 6 | lipin bor
# Processing Record 9 of Set 6 | nara
# Processing Record 10 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 6 | gallup
# Processing Record 11 of Set 6 | csenger
# Processing Record 12 of Set 6 | uk
# City not found. Skipping...
# Processing Record 12 of Set 6 | den helder
# Processing Record 13 of Set 6 | sakaiminato
# Processing Record 14 of Set 6 | moussoro
# Processing Record 15 of Set 6 | areosa
# Processing Record 16 of Set 6 | kholtoson
# Processing Record 17 of Set 6 | esperance
# Processing Record 18 of Set 6 | chakia
# Processing Record 19 of Set 6 | foso
# Processing Record 20 of Set 6 | saint-augustin
# Processing Record 21 of Set 6 | zalantun
# Processing Record 22 of Set 6 | manbij
# Processing Record 23 of Set 6 | mayna
# Processing Record 24 of Set 6 | saint-paul
# Processing Record 25 of Set 6 | sakakah
# City not found. Skipping...
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 6 | nikolskoye
# Processing Record 27 of Set 6 | ancud
# Processing Record 28 of Set 6 | mithimna
# City not found. Skipping...
# Processing Record 28 of Set 6 | bohmte
# Processing Record 29 of Set 6 | lusaka
# Processing Record 30 of Set 6 | binzhou
# Processing Record 31 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | latung
# Processing Record 32 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 6 | outjo
# Processing Record 33 of Set 6 | bongandanga
# Processing Record 34 of Set 6 | thung song
# Processing Record 35 of Set 6 | taltal
# Processing Record 36 of Set 6 | merritt island
# Processing Record 37 of Set 6 | beyneu
# Processing Record 38 of Set 6 | moba
# Processing Record 39 of Set 6 | sioux lookout
# Processing Record 40 of Set 6 | yabelo
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | borama
# City not found. Skipping...
# Processing Record 0 of Set 7 | danville
# Processing Record 1 of Set 7 | halifax
# Processing Record 2 of Set 7 | massakory
# Processing Record 3 of Set 7 | gazanjyk
# Processing Record 4 of Set 7 | lakes entrance
# Processing Record 5 of Set 7 | chokurdakh
# Processing Record 6 of Set 7 | sarkand
# Processing Record 7 of Set 7 | amuntai
# Processing Record 8 of Set 7 | aswan
# Processing Record 9 of Set 7 | castel san pietro terme
# Processing Record 10 of Set 7 | dali
# Processing Record 11 of Set 7 | taksimo
# Processing Record 12 of Set 7 | makkaveyevo
# Processing Record 13 of Set 7 | acarau
# City not found. Skipping...
# Processing Record 13 of Set 7 | huambo
# Processing Record 14 of Set 7 | kirakira
# Processing Record 15 of Set 7 | wageningen
# Processing Record 16 of Set 7 | pisco
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | suluq
# Processing Record 19 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 7 | baker city
# Processing Record 20 of Set 7 | grand-santi
# Processing Record 21 of Set 7 | assiniboia
# Processing Record 22 of Set 7 | ottumwa
# Processing Record 23 of Set 7 | rodeo
# Processing Record 24 of Set 7 | kem
# Processing Record 25 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 25 of Set 7 | kloulklubed
# Processing Record 26 of Set 7 | kavieng
# Processing Record 27 of Set 7 | abu dhabi
# Processing Record 28 of Set 7 | thinadhoo
# Processing Record 29 of Set 7 | mandya
# Processing Record 30 of Set 7 | mount vernon
# Processing Record 31 of Set 7 | yinchuan
# Processing Record 32 of Set 7 | grajewo
# Processing Record 33 of Set 7 | nuevo progreso
# Processing Record 34 of Set 7 | sterling
# Processing Record 35 of Set 7 | dongsheng
# Processing Record 36 of Set 7 | bambous virieux
# Processing Record 37 of Set 7 | micheweni
# Processing Record 38 of Set 7 | cabedelo
# Processing Record 39 of Set 7 | cardston
# Processing Record 40 of Set 7 | mackay
# Processing Record 41 of Set 7 | labrea
# City not found. Skipping...
# Processing Record 41 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 7 | port-gentil
# Processing Record 42 of Set 7 | ratnagiri
# Processing Record 43 of Set 7 | port blair
# Processing Record 44 of Set 7 | talcahuano
# Processing Record 0 of Set 8 | labuhan
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | ranfurly
# Processing Record 3 of Set 8 | ikom
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 8 | kurilsk
# Processing Record 6 of Set 8 | kenora
# Processing Record 7 of Set 8 | lao cai
# Processing Record 8 of Set 8 | zima
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | richards bay
# Processing Record 11 of Set 8 | emba
# Processing Record 12 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 8 | chuy
# Processing Record 13 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 8 | gudur
# Processing Record 14 of Set 8 | huari
# Processing Record 15 of Set 8 | shunyi
# Processing Record 16 of Set 8 | arraial do cabo
# Processing Record 17 of Set 8 | yulara
# Processing Record 18 of Set 8 | puerto escondido
# Processing Record 19 of Set 8 | matagami
# Processing Record 20 of Set 8 | severo-kurilsk
# Processing Record 21 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 8 | padang
# Processing Record 22 of Set 8 | uzventis
# City not found. Skipping...
# Processing Record 22 of Set 8 | tambovka
# Processing Record 23 of Set 8 | salalah
# Processing Record 24 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | pevek
# Processing Record 26 of Set 8 | scottsbluff
# Processing Record 27 of Set 8 | pa sang
# Processing Record 28 of Set 8 | bombay
# Processing Record 29 of Set 8 | shagonar
# Processing Record 30 of Set 8 | poum
# Processing Record 31 of Set 8 | mana
# Processing Record 32 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | buta
# Processing Record 34 of Set 8 | sangin
# Processing Record 35 of Set 8 | progreso
# Processing Record 36 of Set 8 | evensk
# Processing Record 37 of Set 8 | hirara
# Processing Record 38 of Set 8 | aykino
# Processing Record 39 of Set 8 | waipawa
# Processing Record 40 of Set 8 | adrar
# Processing Record 41 of Set 8 | atherton
# Processing Record 42 of Set 8 | mapastepec
# Processing Record 0 of Set 9 | namibe
# Processing Record 1 of Set 9 | baracoa
# Processing Record 2 of Set 9 | ejura
# Processing Record 3 of Set 9 | luanda
# Processing Record 4 of Set 9 | willowmore
# Processing Record 5 of Set 9 | cumberland
# Processing Record 6 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 9 | nador
# Processing Record 7 of Set 9 | buchanan
# Processing Record 8 of Set 9 | ketchikan
# Processing Record 9 of Set 9 | hayden
# Processing Record 10 of Set 9 | srednekolymsk
# Processing Record 11 of Set 9 | murzzuschlag
# Processing Record 12 of Set 9 | kristiansund
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | yatou
# Processing Record 15 of Set 9 | cockburn town
# Processing Record 16 of Set 9 | botwood
# Processing Record 17 of Set 9 | lorengau
# Processing Record 18 of Set 9 | lahad datu
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | kapit
# Processing Record 21 of Set 9 | sangar
# Processing Record 22 of Set 9 | portland
# Processing Record 23 of Set 9 | mango
# Processing Record 24 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 9 | osasco
# Processing Record 25 of Set 9 | sao felix do xingu
# Processing Record 26 of Set 9 | wenling
# Processing Record 27 of Set 9 | luz
# Processing Record 28 of Set 9 | sirjan
# Processing Record 29 of Set 9 | tres passos
# Processing Record 30 of Set 9 | piacabucu
# Processing Record 31 of Set 9 | saint-joseph
# Processing Record 32 of Set 9 | avera
# Processing Record 33 of Set 9 | chara
# Processing Record 34 of Set 9 | isangel
# Processing Record 35 of Set 9 | eureka
# Processing Record 36 of Set 9 | santa ana
# Processing Record 37 of Set 9 | champerico
# Processing Record 38 of Set 9 | picota
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | ingham
# Processing Record 41 of Set 9 | stokmarknes
# Processing Record 42 of Set 9 | tias
# Processing Record 43 of Set 9 | itapecerica da serra
# Processing Record 44 of Set 9 | mahalapye
# Processing Record 45 of Set 9 | inuvik
# Processing Record 46 of Set 9 | laguna
# Processing Record 47 of Set 9 | lata
# Processing Record 0 of Set 10 | auray
# Processing Record 1 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 10 | artyom
# Processing Record 2 of Set 10 | camacupa
# Processing Record 3 of Set 10 | torbay
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | smithers
# Processing Record 6 of Set 10 | kangaatsiaq
# Processing Record 7 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 10 | egvekinot
# Processing Record 8 of Set 10 | mata
# Processing Record 9 of Set 10 | erzin
# Processing Record 10 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 10 | shelburne
# Processing Record 11 of Set 10 | umm lajj
# Processing Record 12 of Set 10 | kondagaon
# Processing Record 13 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 10 | san carlos de bariloche
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 10 | luau
# Processing Record 16 of Set 10 | mount gambier
# Processing Record 17 of Set 10 | abha
# Processing Record 18 of Set 10 | banda aceh
# Processing Record 19 of Set 10 | okhotsk
# Processing Record 20 of Set 10 | nishihara
# Processing Record 21 of Set 10 | tura
# Processing Record 22 of Set 10 | dingle
# Processing Record 23 of Set 10 | oranjestad
# Processing Record 24 of Set 10 | ust-nera
# Processing Record 25 of Set 10 | japura
# Processing Record 26 of Set 10 | anicuns
# Processing Record 27 of Set 10 | porto santo
# City not found. Skipping...
# Processing Record 27 of Set 10 | krasnyy yar
# Processing Record 28 of Set 10 | pitimbu
# Processing Record 29 of Set 10 | muros
# Processing Record 30 of Set 10 | kushima
# Processing Record 31 of Set 10 | itarema
# Processing Record 32 of Set 10 | mayor pablo lagerenza
# Processing Record 33 of Set 10 | bubaque
# Processing Record 34 of Set 10 | auch
# Processing Record 35 of Set 10 | lugovoy
# Processing Record 36 of Set 10 | male
# Processing Record 37 of Set 10 | alexandria
# Processing Record 38 of Set 10 | berlevag
# Processing Record 39 of Set 10 | mendi
# Processing Record 40 of Set 10 | saint-philippe
# Processing Record 41 of Set 10 | ziarat
# Processing Record 42 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 10 | taoudenni
# Processing Record 0 of Set 11 | samarai
# Processing Record 1 of Set 11 | teknaf
# Processing Record 2 of Set 11 | zhangye
# Processing Record 3 of Set 11 | goba
# Processing Record 4 of Set 11 | boundiali
# Processing Record 5 of Set 11 | lazaro cardenas
# Processing Record 6 of Set 11 | presidencia roque saenz pena
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | karamken
# City not found. Skipping...
# Processing Record 8 of Set 11 | eldama ravine
# Processing Record 9 of Set 11 | kirkenaer
# Processing Record 10 of Set 11 | vila velha
# Processing Record 11 of Set 11 | turbat
# Processing Record 12 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 11 | san borja
# Processing Record 13 of Set 11 | vao
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 11 | linxia
# Processing Record 15 of Set 11 | amga
# Processing Record 16 of Set 11 | rosetta
# Processing Record 17 of Set 11 | sardarshahr
# Processing Record 18 of Set 11 | bizhbulyak
# Processing Record 19 of Set 11 | babstovo
# Processing Record 20 of Set 11 | bunol
# Processing Record 21 of Set 11 | ghanzi
# Processing Record 22 of Set 11 | northam
# Processing Record 23 of Set 11 | dillon
# Processing Record 24 of Set 11 | mayumba
# Processing Record 25 of Set 11 | naryan-mar
# Processing Record 26 of Set 11 | maniitsoq
# Processing Record 27 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 11 | luzhou
# Processing Record 28 of Set 11 | valentin gomez farias
# Processing Record 29 of Set 11 | chulman
# Processing Record 30 of Set 11 | jalu
# Processing Record 31 of Set 11 | luwingu
# Processing Record 32 of Set 11 | derzhavinsk
# Processing Record 33 of Set 11 | darhan
# Processing Record 34 of Set 11 | sabha
# Processing Record 35 of Set 11 | khandyga
# Processing Record 36 of Set 11 | ekhabi
# Processing Record 37 of Set 11 | del rio
# Processing Record 38 of Set 11 | parrita
# Processing Record 39 of Set 11 | tecoanapa
# Processing Record 40 of Set 11 | misratah
# Processing Record 41 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 11 | coffs harbour
# Processing Record 42 of Set 11 | san rafael del sur
# Processing Record 0 of Set 12 | necochea
# Processing Record 1 of Set 12 | sola
# Processing Record 2 of Set 12 | srandakan
# Processing Record 3 of Set 12 | wajid
# Processing Record 4 of Set 12 | linjiang
# Processing Record 5 of Set 12 | mirnyy
# Processing Record 6 of Set 12 | requena
# Processing Record 7 of Set 12 | tanout
# Processing Record 8 of Set 12 | takab
# Processing Record 9 of Set 12 | isla mujeres
# Processing Record 10 of Set 12 | broken hill
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | millport
# Processing Record 13 of Set 12 | calvinia
# Processing Record 14 of Set 12 | bahia honda
# Processing Record 15 of Set 12 | praia da vitoria
# Processing Record 16 of Set 12 | iglesias
# Processing Record 17 of Set 12 | coihaique
# Processing Record 18 of Set 12 | trat
# Processing Record 19 of Set 12 | husavik
# Processing Record 20 of Set 12 | wolgast
# Processing Record 21 of Set 12 | puerto del rosario
# Processing Record 22 of Set 12 | malanje
# Processing Record 23 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 12 | khudumelapye
# Processing Record 24 of Set 12 | jieshi
# Processing Record 25 of Set 12 | oussouye
# Processing Record 26 of Set 12 | antalaha
# Processing Record 27 of Set 12 | mnogovershinnyy
# Processing Record 28 of Set 12 | sciacca
# Processing Record 29 of Set 12 | venado tuerto
# Processing Record 30 of Set 12 | augusto correa
# Processing Record 31 of Set 12 | machilipatnam
# Processing Record 32 of Set 12 | mahanoro
# Processing Record 33 of Set 12 | horizontina
# Processing Record 34 of Set 12 | santa cruz
# Processing Record 35 of Set 12 | pingliang
# Processing Record 36 of Set 12 | lerwick
# Processing Record 37 of Set 12 | makrana
# Processing Record 38 of Set 12 | amapa
# Processing Record 39 of Set 12 | kyshtovka
# Processing Record 40 of Set 12 | umm kaddadah
# Processing Record 41 of Set 12 | marsh harbour
# Processing Record 42 of Set 12 | bahia blanca
# Processing Record 43 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 12 | joshimath
# Processing Record 44 of Set 12 | trogir
# Processing Record 45 of Set 12 | kortkeros
# Processing Record 46 of Set 12 | kudahuvadhoo
# Processing Record 47 of Set 12 | tibati
# Processing Record 0 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 0 of Set 13 | khor
# Processing Record 1 of Set 13 | helong
# Processing Record 2 of Set 13 | vernon
# Processing Record 3 of Set 13 | gizo
# Processing Record 4 of Set 13 | mehamn
# Processing Record 5 of Set 13 | boa vista
# Processing Record 6 of Set 13 | sumenep
# Processing Record 7 of Set 13 | esmeraldas
# Processing Record 8 of Set 13 | maputo
# Processing Record 9 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 9 of Set 13 | rameswaram
# Processing Record 10 of Set 13 | camapua
# Processing Record 11 of Set 13 | kalengwa
# Processing Record 12 of Set 13 | beloha
# Processing Record 13 of Set 13 | tonantins
# Processing Record 14 of Set 13 | hamilton
# Processing Record 15 of Set 13 | dezful
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | luwuk
# Processing Record 18 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 13 | aqtobe
# Processing Record 19 of Set 13 | namatanai
# Processing Record 20 of Set 13 | maarianhamina
# City not found. Skipping...
# Processing Record 20 of Set 13 | tessalit
# Processing Record 21 of Set 13 | ucluelet
# Processing Record 22 of Set 13 | hervey bay
# Processing Record 23 of Set 13 | arcata
# Processing Record 24 of Set 13 | fairbanks
# Processing Record 25 of Set 13 | batagay-alyta
# Processing Record 26 of Set 13 | zhob
# Processing Record 27 of Set 13 | xuddur
# Processing Record 28 of Set 13 | pakdasht
# End of Data Retrieval
# ------------------------

# %%
weather_dict = {
     "city": city_name,
     "cloudiness": cloudiness,
     "country": country,
     "date": date,
     "humidity": humidity,
     "lat": lat,
     "lng": lng,
     "max_temp": max_temp,
     "wind_speed": wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# city          567
# cloudiness    567
# country       567
# date          567
# humidity      567
# lat           567
# lng           567
# max_temp      567
# wind_speed    567
# dtype: int64

# %%
weather_data.to_csv("output_data/cities.csv")

weather_data.head()
# Out:
#             city  cloudiness country        date  humidity    lat    lng  \
# 0         Kalabo           0      ZM  1567615025        21 -15.00  22.67
# 1  San Cristobal         100      HN  1567615025        30  14.68 -86.92
# 2     Sao Filipe           0      CV  1567615025        83  14.90 -24.50
# 3        Pathein         100      MM  1567614873        89  16.78  94.73
# 4      Cape Town          20      ZA  1567614940        67 -33.93  18.42
#
#    max_temp  wind_speed
# 0     76.37        5.03
# 1     88.25       10.40
# 2     81.05       12.15
# 3     79.25       10.96
# 4     62.01       24.16

# %%
#latitude vs. Temperature Plot
weather_data.plot(kind="scatter", x="lat", y="max_temp", edgecolors="black", grid=True)

plt.title("City Latitude vs. Max Temperature (09/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlim(-60, 85)
plt.ylim(25, 105)
# Out:
# (25, 105)

# %%
#Latitude Vs. Humidity
weather_data.plot(kind="scatter", x="lat", y="humidity", edgecolors="black", grid=True)

plt.title("City Latitude vs. Humidity (09/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-60, 85)
plt.ylim(25, 105)
# Out:
# (25, 105)

# %%
#Latitude Vs. Cloudiness
weather_data.plot(kind="scatter", x="lat", y="cloudiness", edgecolors="black", grid=True)

plt.title("City Latitude vs. Cloudiness (09/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-60, 85)
plt.ylim(25, 105)
# Out:
# (25, 105)

# %%
#Latitude Vs. Wind Speed 
weather_data.plot(kind="scatter", x="lat", y="wind_speed", edgecolors="black", grid=True)

plt.title("City Latitude vs. Wind Speed (09/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-60, 85)
plt.ylim(0, 35)
# Out:
# (0, 35)
